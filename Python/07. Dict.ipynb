# %% [markdown]
# ## dict

# %%
json

# %%
d1 = {}

# %%
type(d1)
# Out:
# dict

# %%
colors = {1: "Red", 2: "Blue",3: "Green", 4: "Yellow",  5: "Black"}

# %%
fruits = {
    1: "Apple",
    2: "Banana",
    3: "Mango",
    4: "Orange",
    5: "Grapes"
}

# %%
colors+fruits
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 colors+fruits
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
colors*2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 colors*2
#
# TypeError: unsupported operand type(s) for *: 'dict' and 'int'

# %%
colors
# Out:
# {1: 'Red', 2: 'Blue', 3: 'Green', 4: 'Yellow', 5: 'Black'}

# %%
colors[4]
# Out:
# 'Yellow'

# %%
colors[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 colors[0]
#
# KeyError: 0

# %%
colors[5]
# Out:
# 'Black'

# %%
colors["Red"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 colors["Red"]
#
# KeyError: 'Red'

# %%
colors[:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 colors[:]
#
# TypeError: unhashable type: 'slice'

# %%
colors[2, 3, 4]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 colors[2, 3, 4]
#
# KeyError: (2, 3, 4)

# %%
colors[4] = "Orange"

# %%
colors
# Out:
# {1: 'Red', 2: 'Blue', 3: 'Green', 4: 'Orange', 5: 'Black'}

# %%
c1 = {1: 'Red', 2: 'Blue', 3: 'Green', 4: 'Orange', 5: 'Black', 2: "yellow"}

# %%
c1
# Out:
# {1: 'Red', 2: 'yellow', 3: 'Green', 4: 'Orange', 5: 'Black'}

# %%
c1 = {1: 'Red', 2: 'Blue', 3: 'Green', 4: 'Orange', 5: 'Black', 6: "Blue"}

# %%
c1
# Out:
# {1: 'Red', 2: 'Blue', 3: 'Green', 4: 'Orange', 5: 'Black', 6: 'Blue'}

# %%
"Red" in c1
# Out:
# False

# %%
1 in c1
# Out:
# True

# %%
11 in c1
# Out:
# False

# %%
colors is c1
# Out:
# False

# %%
colors
# Out:
# {1: 'Red', 2: 'Blue', 3: 'Green', 4: 'Orange', 5: 'Black'}

# %%
c1
# Out:
# {1: 'Red', 2: 'Blue', 3: 'Green', 4: 'Orange', 5: 'Black', 6: 'Blue'}

# %% [markdown]
# ### dict

# %%
fruits
# Out:
# {1: 'Apple', 2: 'Banana', 3: 'Mango', 4: 'Orange', 5: 'Grapes'}

# %%
fruits.get(2)
# Out:
# 'Banana'

# %%
fruits[2]
# Out:
# 'Banana'

# %%
fruits[7]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 fruits[7]
#
# KeyError: 7

# %%
fruits.get(7)

# %%
fruits.values()
# Out:
# dict_values(['Apple', 'Banana', 'Mango', 'Orange', 'Grapes'])

# %%
fruits.keys()
# Out:
# dict_keys([1, 2, 3, 4, 5])

# %%
fruits.items()
# Out:
# dict_items([(1, 'Apple'), (2, 'Banana'), (3, 'Mango'), (4, 'Orange'), (5, 'Grapes')])

# %%
fruits.pop(5)
# Out:
# 'Grapes'

# %%
fruits
# Out:
# {1: 'Apple', 2: 'Banana', 3: 'Mango', 4: 'Orange'}

# %%
fruits.popitem()
# Out:
# (4, 'Orange')

# %%
fruits.popitem()
# Out:
# (3, 'Mango')

# %%
fruits
# Out:
# {1: 'Apple', 2: 'Banana'}

# %%
fruits.pop(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 fruits.pop(5)
#
# KeyError: 5

# %%
fruits.update()

# %%
fruits
# Out:
# {1: 'Apple', 2: 'Banana'}

# %%
fruits.update(colors)

# %%
fruits
# Out:
# {1: 'Red', 2: 'Blue', 3: 'Green', 4: 'Orange', 5: 'Black'}

# %%
fruits.update({6: 'Apple', 7: 'Banana'})

# %%
fruits
# Out:
# {1: 'Red',
#  2: 'Blue',
#  3: 'Green',
#  4: 'Orange',
#  5: 'Black',
#  6: 'Apple',
#  7: 'Banana'}

# %%
fruits[8] = None

# %%
fruits
# Out:
# {1: 'Red',
#  2: 'Blue',
#  3: 'Green',
#  4: 'Orange',
#  5: 'Black',
#  6: 'Apple',
#  7: 'Banana',
#  8: None}

# %%
fruits[3] ="Green apple"

# %%
fruits
# Out:
# {1: 'Red',
#  2: 'Blue',
#  3: 'Green apple',
#  4: 'Orange',
#  5: 'Black',
#  6: 'Apple',
#  7: 'Banana',
#  8: None}

# %%
#d2 = {key : value}
d2 = { int/float/True/complex/str/tuple   : }

# %%
data = {
    "colors": {
        1: "Red",
        2: "Blue",
        3: "Green",
        4: "Yellow",
        5: "Black"
    },

    "fruits": {
        1: "Apple",
        2: "Banana",
        3: "Mango",
        4: "Orange",
        5: "Grapes"
    },

    "months": {
        1: "January",
        2: "February",
        3: "March",
        4: "April",
        5: "May"
    }
}

# %%
data
# Out:
# {'colors': {1: 'Red', 2: 'Blue', 3: 'Green', 4: 'Yellow', 5: 'Black'},
#  'fruits': {1: 'Apple', 2: 'Banana', 3: 'Mango', 4: 'Orange', 5: 'Grapes'},
#  'months': {1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May'}}

# %%
data["fruits"][3]
# Out:
# 'Mango'

# %%
data["months"][4]
# Out:
# 'April'

# %%
data = {
    "colors": {
        1: "Red",
        2: "Blue",
        3: "Green",
        4: "Yellow",
        5: "Black"
    },

    "fruits": [{
        1: "Apple",
        2: "Banana"},
        {3: "Mango",
        4: "Orange",
        5: "Grapes"}
    ],

    "months": {
        1: "January",
        2: "February",
        3: "March",
        4: "April",
        5: "May"
    }
}

# %%
data
# Out:
# {'colors': {1: 'Red', 2: 'Blue', 3: 'Green', 4: 'Yellow', 5: 'Black'},
#  'fruits': [{1: 'Apple', 2: 'Banana'}, {3: 'Mango', 4: 'Orange', 5: 'Grapes'}],
#  'months': {1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May'}}

# %%
data["fruits"][1][4].lower()
# Out:
# 'orange'

# %%
data = {
    "colors": {
        1: ["Red","Blue","Green"],
        "Yellow":
     "Black"
    },

    "fruits": [{
        1: "Apple",
        2: "Banana"},
        {3: "Mango",
        4: "Orange",
        5: "Grapes"}
    ],

    "months": {
        ("January",
        "February",
        "March"),
        "April",
        "May"
    }
}

# %%
data
# Out:
# {'colors': {1: ['Red', 'Blue', 'Green'], 'Yellow': 'Black'},
#  'fruits': [{1: 'Apple', 2: 'Banana'}, {3: 'Mango', 4: 'Orange', 5: 'Grapes'}],
#  'months': {('January', 'February', 'March'), 'April', 'May'}}

# %%
data["months"].
# Out:
# {('January', 'February', 'March'), 'April', 'May'}

# %%
data["colors"].items()
# Out:
# dict_items([(1, ['Red', 'Blue', 'Green']), ('Yellow', 'Black')])

# %%
data["colors"][1]
# Out:
# ['Red', 'Blue', 'Green']

# %%
lis = [1,2,3, ('Red', 'Blue', 'Green', {1: 'Apple', 2: {'Banana''January', 'February', 'March'}})]

# %%
lis
# Out:
# [1,
#  2,
#  3,
#  ('Red',
#   'Blue',
#   'Green',
#   {1: 'Apple', 2: {'BananaJanuary', 'February', 'March'}})]

# %%
lis[3][3][2]
# Out:
# {'BananaJanuary', 'February', 'March'}

# %%
variables
operators
typecasting
builtin
string formating
