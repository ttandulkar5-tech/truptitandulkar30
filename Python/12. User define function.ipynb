# %% [markdown]
# ## user defined

# %%
def fun_name():
    return "hello "

# %%
fun_name()
# Out:
# 'hello '

# %%
def fun1(a, b):
    c = a+b
    return c

# %%
fun1(10, 20, 30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 fun1(10, 20, 30)
#
# TypeError: fun1() takes 2 positional arguments but 3 were given

# %%
def fun2(x, y):
    return x, y

# %%
fun2(20, 25)
# Out:
# (20, 25)

# %%
def fun3(*args):
    return args

# %%
fun3(3434,4,8,5,56)
# Out:
# (3434, 4, 8, 5, 56)

# %%
len("asdf", "sdfgsajd")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 len("asdf", "sdfgsajd")
#
# TypeError: len() takes exactly one argument (2 given)

# %%
print(3,4,6,6,)
# Out:
# 3 4 6 6

# %%
positional argument
*argument
**key-word argument

# %%
def fun4(**kw):
    return kw

# %%
fun4(a = 8, b = 9, c = 4)
# Out:
# {'a': 8, 'b': 9, 'c': 4}

# %%
def fun5(**kw, *k, a):
    return a, k, kw
# Out:
#   Cell In[35], line 1
#     def fun5(**kw, *k, a):
#                    ^
# SyntaxError: arguments cannot follow var-keyword argument

# %%
def fun5(*k, a, **kw ):
    return a, k, kw

# %%
fun5(5, 8, name = 9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 fun5(5, 8, name = 9)
#
# TypeError: fun5() missing 1 required keyword-only argument: 'a'

# %%
def fun5( a,*k, **kw ):
    return a, k, kw

# %%
fun5(5, 8, 9,4, py = 67, xy = 66)
# Out:
# (5, (8, 9, 4), {'py': 67, 'xy': 66})

# %%
def area(r):
    pi = 3.14
    a = pi*r**2
    return f'area of circle {a} in cmsquare'

# %%
area(7)
# Out:
# 'area of circle 153.86 in cmsquare'

# %%
area(89)
# Out:
# 'area of circle 24871.940000000002 in cmsquare'

# %%
def area(r):
    import math
    a = math.pi*r**2
    return f'area of circle {a} in cmsquare'
    return "hello"

# %%
area(10)
# Out:
# 'area of circle 314.1592653589793 in cmsquare'

# %%
def area(r):
    import math
    a = math.pi*r**2
    print( f'area of circle {a} in cmsquare')
    print("hello")

# %%
area(4)
# Out:
# area of circle 50.26548245743669 in cmsquare
# hello

# %%
def greeting(name):
    x = "hello "
    print(x+name)

# %%
greeting("rohit")
# Out:
# hello rohit

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
y = "hiii.. "

# %%
y
# Out:
# 'hiii..'

# %%
def greeting(name):
    x = "hello "
    print(x+name)
    print(y+name)

# %%
greeting("sagar")
# Out:
# hello sagar
# hiii.. sagar

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
def greeting(name):
    global x
    x = "hello "
    print(x+name)
    print(y+name)

# %%
greeting("amit")
# Out:
# hello amit
# hiii.. amit

# %%
y
# Out:
# 'hiii.. '

# %%
x
# Out:
# 'hello '

# %%
def printname(name="amit"):
    return name

# %%
printname("deepak")
# Out:
# 'deepak'

# %%
printname("deepak", "shubham")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 printname("deepak", "shubham")
#
# TypeError: printname() takes from 0 to 1 positional arguments but 2 were given

# %%
def even(num):
    if num%2==0:
        print("even number")
    else:
        print("odd number")

# %%
even(79)
# Out:
# odd number

# %%
def circle(rad, metric):
    pi = 3.14
    if metric == "area":
        a = pi*rad**2
        print(f"area {a}")
    else:
        p = 2*pi*rad
        print(f"perimeter {p}")

# %%
def choice(areaa,perimeter):
    if areaa==1:
        r= int(input("enter radius"))
        pi =3.14
        a=pi*r**2
        print(a)
    if perimeter==1:
        re=int(input("enter radi"))
        pi=3.14
        pr = 2*pi*re
        print("perimeter",pr)

# %%
choice(0,1)
# Out:
# enter radi 8
# perimeter 50.24

# %%
circle(50, "perimeter")
# Out:
# perimeter 314.0

# %%
[1,2,"i",4,4,"a", "u", "7", 9,3,32]
# Out:
# [1, 2, 'i', 4, 4, 'a', 'u', '67', 9, 3, 32]

# %%
"i a u 7"
