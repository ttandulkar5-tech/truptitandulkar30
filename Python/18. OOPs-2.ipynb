# %%
class person4:                             # parents class

    name = "amit"
    surname = "kumar"
    yob = 1993

    def age(self , current_year ):
        return current_year - self.yob
    
    def age1(self , current_year ):
        return current_year - self.yob

# %%
obj = person4()

# %%
obj.yob
# Out:
# 1993

# %%
class employee(person4):           #child class
    name1 = "sumit"     
    surname1 = "singh"
    yob1 = 1991

# %%
obj1 = employee()

# %%
obj1.name
# Out:
# 'amit'

# %%
obj1.name1
# Out:
# 'sumit'

# %%
class bank :             # perents class 
    def transaction(self) :
        print("total transaction value ")
    def account_opening(self):
        print("this will show you your account open status ")
    def deposite(self):
        print("this will show your deposited amount")

# %%
class HDFC_bank(bank):             # child class
    def hdfc_to_icici(self):
        print("this will show you all the transaction happend to icici throuhg hdfc")

# %%
obj2 = HDFC_bank()

# %%
obj2.transaction()
# Out:
# total transaction value

# %%
class icici(HDFC_bank): 
    pass

# %%
obj3 = icici()

# %%
obj3.deposite()
# Out:
# this will show your deposited amount

# %%
class bank :
    def transaction(self) :
        print("total transaction value ")
    def account_opening(self):
        print("this will show you your account open status ")
    def deposite(self):
        print("this will show your deposited amount")
    def test(self):                          # override code
        print("this is a test methond form bank class ")

# %%
class HDFC_bank:
    def hdfc_to_icici(self):
        print("this will show you all the transaction happend to icici throuhg hdfc")
    def test(self):           #override code
        print("this is a test method form hdfc bank ")

# %%
class ineron_bank:
    def account_status_icici(self):
        print("print a account status in icici ")

# %%
class icici(bank,  HDFC_bank,  ineron_bank):
    pass

# %%
obj4 = icici()

# %%
obj4.account_opening()
# Out:
# this will show you your account open status

# %%
obj4.hdfc_to_icici()
# Out:
# this will show you all the transaction happend to icici throuhg hdfc

# %%
obj4.account_status_icici()
# Out:
# print a account status in icici

# %%
obj4.test()
# Out:
# this is a test methond form bank class

# %%
# Parent class
class Vehicle:
    def start(self):
        print("Vehicle started")

# Child class 1
class Car(Vehicle):
    def drive(self):
        print("Driving a car")

# Child class 2
class Bike(Vehicle):
    def ride(self):
        print("Riding a bike")

# %%
obj5 = Bike()

# %%
obj5.start()
# Out:
# Vehicle started

# %%
# Parent class
class Vehicle:
    def general_info(self):
        print("Vehicles are used for transportation.")

# Child class 1 (inherits from Vehicle)
class Car(Vehicle):
    def car_info(self):
        print("Car has 4 wheels.")

# Child class 2 (inherits from Vehicle)
class Bike(Vehicle):
    def bike_info(self):
        print("Bike has 2 wheels.")

# Grandchild class (inherits from both Car and Bike)
class Electric(Car, Bike):
    def electric_info(self):
        print("Electric bike runs on battery.")

# Create object of ElectricBike
ebike = Electric()

# %%
Electric.mro()
# Out:
# [__main__.Electric, __main__.Car, __main__.Bike, __main__.Vehicle, object]

# %%
class vehicle:

    def start(self):
        print("Vehicle started")

# %%
class car(vehicle):

    def carvehicle(self):
        print("this is from car class")

# %%
class bike(vehicle):
    
    def bikevehicle(self):
        print("you are riding bike")

# %%
class petrolcar(car):
     def pc(self):
         print("this is petrol car method")

# %%
obj7 = petrolcar()

# %%
obj7.

# %%
class dieselcar(car):
    def dc(self):
        print("this is diesel car method")

# %%
obj8 = dieselcar()

# %%
class kia(dieselcar):
    def kiacar(self):
        print("this is kia car")

# %%
obj9 = kia()

# %%
obj9.kiacar()
# Out:
# this is kia car

# %%
class vehicle:

    def start(self):
        print("Vehicle started")
        
class car(vehicle):
        print("this is from car class")

def petrol(car):

    def petrolcar():
        print("this is petrolcar")

def diesel(car):

    def dieselcar():
        print("this is dieselcar")

def ev(car):

    def evcar():
        print("this is ev car")


def bike(vehicle):
    
    def bikevehicle():
        print("you are riding bike")
        
def petrol(bike):

    def petrolbike():
        print("the bike runs on petrol")

def ev(bike):    

    def evbike():
        print("this is ev bike")

# %%
class bank :
    def transaction(self) :
        print("total transaction value ")
    def account_opening(self):
        print("this will show you your account open status ")
    def deposite(self):
        print("this will show your deposited amount")
    def test(self):                          # override code
        print("this is a test methond form bank class ")

# %%
class HDFC_bank(bank):
    def hdfc_to_icici(self):
        print("this will show you all the transaction happend to icici throuhg hdfc")
    def test(self):           #override code
        print("this is a test method form hdfc bank ")

# %%
obj = bank()

# %%
obj.deposite()
# Out:
# this will show your deposited amount

# %%
hobj = HDFC_bank()

# %%
hobj.
