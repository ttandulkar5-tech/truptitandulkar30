# %%
print("hello world")
# Out:
# hello world

# %%
print("hello \nworld")
# Out:
# hello
# world

# %%
print("hello \tworld")
# Out:
# hello 	world

# %%
s1 = "Connect with MongoDB experts, AI innovators, 
and tech leaders and get the skills you need to build
great application experiences for a new generation of users."
# Out:
#   Cell In[4], line 1
#     s1 = "Connect with MongoDB experts, AI innovators,
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s1 = """Connect with MongoDB experts, AI innovators, 
and tech leaders and get the skills you need to build
great application experiences for a new generation of users."""

# %%
s1
# Out:
# 'Connect with MongoDB experts, AI innovators, \nand tech leaders and get the skills you need to build\ngreat application experiences for a new generation of users.'

# %%
date = "1947"

# %%
print(date)
# Out:
# 1947

# %%
date = '"1947"'

# %%
print(date)
# Out:
# "1947"

# %%
date = "'1947'"

# %%
print(date)
# Out:
# '1947'

# %%
name = "amit"
profession = "trainer"
subject = "datascience"

# %%
print(name, profession, subject)
# Out:
# amit trainer datascience

# %%
print("my name is", name, "my profession is", profession, "learning ", subject)
# Out:
# my name is amit my profession is trainer learning  datascience

# %%
# %s, %d, %.f

# %%
"my name is %s, my profession is %s, ---  i am learning %s"%(name, profession, subject)
# Out:
# 'my name is amit, my profession is trainer, ---  i am learning datascience'

# %%
"my name is %s, my profession is %s, ---  i am learning %s"%(name, profession, subject)
# Out:
# 'my name is amit, my profession is trainer, ---  i am learning datascience'

# %%
age = 30
lang = 3.14

# %%
"my name is %s,%d my profession is %s, ---  i am learning %s %.2f"%(name,age, profession, subject, lang)
# Out:
# 'my name is amit,30 my profession is trainer, ---  i am learning datascience 3.14'

# %%
"my name is {} my profession is {}, ---  i am learning {}  {}".format(name, profession, subject, age)
# Out:
# 'my name is amit my profession is trainer, ---  i am learning datascience  30'

# %%
f"my name is {name} my profession is {profession}, ---  i am learning {subject}  {8765}"
# Out:
# 'my name is amit my profession is trainer, ---  i am learning datascience  8765'

# %%
f"askdfh {var}"

# %%
r''

# %%
"C:\\Users\\amitm\\Downloads\\Screenshot 2026-07-27 021310.png"

# %%
"C:/Users/amitm/Downloads/Screenshot 2026-07-27 021310.png"

# %%
print(name)
print(profession)
print(subject)
# Out:
# amit
# trainer
# datascience

# %%
print(name, end = " ")
print(profession, end = " ")
print(subject)
# Out:
# amit trainer datascience

# %%
var = "this is my first string variable"

# %%
var
# Out:
# 'this is my first string variable'

# %% [markdown]
# ## concat

# %%
var + name
# Out:
# 'this is my first string variableamit'

# %%
var + " " + name + profession
# Out:
# 'this is my first string variable amittrainer'

# %% [markdown]
# ## repeatation

# %%
name * 3
# Out:
# 'amitamitamit'

# %%
var*3
# Out:
# 'this is my first string variablethis is my first string variablethis is my first string variable'

# %% [markdown]
# ## indexing

# %%
var
# Out:
# 'this is my first string variable'

# %%
var[6]
# Out:
# 's'

# %%
var[1]
# Out:
# 'h'

# %%
var[-3]
# Out:
# 'b'

# %% [markdown]
# ## slicing

# %%
var
# Out:
# 'this is my first string variable'

# %%
var[2:15]
# Out:
# 'is is my firs'

# %%
var[1:5]
# Out:
# 'his '

# %%
var[4:]
# Out:
# ' is my first string variable'

# %%
var[:10]
# Out:
# 'this is my'

# %%
var[4:20:2]
# Out:
# ' sm is t'

# %%
var[::4]
# Out:
# 't mi iva'

# %%
var
# Out:
# 'this is my first string variable'

# %%
var[::-1]
# Out:
# 'elbairav gnirts tsrif ym si siht'

# %%
var[2:10:-2]
# Out:
# ''

# %%
var[20:5:-2]
# Out:
# 'it si ms'

# %% [markdown]
# ## mutation

# %%
var
# Out:
# 'this is my first string variable'

# %%
var[5]  = "I"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 var[5]  = "I"
#
# TypeError: 'str' object does not support item assignment

# %%
subject
# Out:
# 'datascience'

# %%
subject[1:7]
# Out:
# 'atasci'

# %%
subject[8:2:-1]
# Out:
# 'neicsa'

# %%
"Data" in subject
# Out:
# False

# %%
"data" in subject
# Out:
# True

# %%
s1
# Out:
# 'Connect with MongoDB experts, AI innovators, \nand tech leaders and get the skills you need to build\ngreat application experiences for a new generation of users.'

# %%
"skills" in s1
# Out:
# True

# %%
"data" is "DATA"
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\amitm\AppData\Local\Temp\ipykernel_16912\3235354553.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   "data" is "DATA"
# False

# %%
name is subject
# Out:
# False

# %%
sub
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 sub
#
# NameError: name 'sub' is not defined

# %%
open("new.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 open("new.txt")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'new.txt'

# %%
len(765)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 len(765)
#
# TypeError: object of type 'int' has no len()

# %%
4/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 4/0
#
# ZeroDivisionError: division by zero

# %%
ds_lang = "python"

# %%
ds_lang
# Out:
# 'python'

# %% [markdown]
# ## Functions

# %%
var
# Out:
# 'this is my first string variable'

# %%
type(var)
# Out:
# str

# %%
var.

# %%
l1 = []

# %%
l1.

# %%
t1 = ()

# %%
t1.

# %%
var
# Out:
# 'this is my first string variable'

# %%
var.upper()
# Out:
# 'THIS IS MY FIRST STRING VARIABLE'

# %%
var
# Out:
# 'this is my first string variable'

# %%
var = var.upper()

# %%
var
# Out:
# 'THIS IS MY FIRST STRING VARIABLE'

# %%
var.lower()
# Out:
# 'this is my first string variable'

# %%
var.capitalize()
# Out:
# 'This is my first string variable'

# %%
title = var.title()

# %%
title
# Out:
# 'This Is My First String Variable'

# %%
title.swapcase()
# Out:
# 'tHIS iS mY fIRST sTRING vARIABLE'

# %%
var.center(90, " ")
# Out:
# '                             THIS IS MY FIRST STRING VARIABLE                             '

# %%
s2 = "python3.11"

# %%
s2.isalnum()
# Out:
# True

# %%
s2 = "python311"

# %%
s2.isalpha()
# Out:
# False

# %%
name.isalpha()
# Out:
# True

# %%
var.isalpha()
# Out:
# False

# %%
var.isspace()
# Out:
# False

# %%
sp = "   "

# %%
sp.isspace()
# Out:
# True

# %%
name.islower()
# Out:
# True

# %%
name.isupper()
# Out:
# False

# %%
name
# Out:
# 'amit'

# %%
var
# Out:
# 'THIS IS MY FIRST STRING VARIABLE'

# %%
var.startswith("THIS")
# Out:
# True

# %%
var.endswith("LE")
# Out:
# True

# %%
var.endswith("ABL")
# Out:
# False

# %%
var
# Out:
# 'THIS IS MY FIRST STRING VARIABLE'

# %%
var.count("I")
# Out:
# 5

# %%
var.index("H")
# Out:
# 1

# %%
var.find("I")
# Out:
# 2

# %%
var.rfind("I")
# Out:
# 27

# %%
var
# Out:
# 'THIS IS MY FIRST STRING VARIABLE'

# %%
var = var.lower()

# %%
var
# Out:
# 'this is my first string variable'

# %%
var.index("i", 7)
# Out:
# 12
