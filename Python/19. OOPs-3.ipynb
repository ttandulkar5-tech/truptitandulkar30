# %%
class Parent:
    def show(self):
        print("Parent's show method")


class Child(Parent):
    pass

# %%
obj = Child()

# %%
obj.show()
# Out:
# Parent's show method

# %%
class Parent:
    def show(self):
        print("Parent's method")


class Child(Parent):
    def show(self):
        print("Child's method")
        super().show()

# %%
obj = Child()

# %%
obj.show()
# Out:
# Child's method
# Parent's method

# %%
class Parent:
    def show(self):
        print("Parent's method")


class Child(Parent):
    def show(self):
        super().show()
        print("Child's method")

# %%
obj = Child()

# %%
obj.show()
# Out:
# Parent's method
# Child's method

# %%
class Parent:
    def show(self):
        print("Parent's method")


class Child(Parent):

    super().show()
    def show(self):
        print("Child's method")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 6
#       2     def show(self):
#       3         print("Parent's method")
# ----> 6 class Child(Parent):
#       8     super().show()
#       9     def show(self):
#
# Cell In[13], line 8, in Child()
#       6 class Child(Parent):
# ----> 8     super().show()
#       9     def show(self):
#      10         print("Child's method")
#
# RuntimeError: super(): no arguments

# %%
class BankAccount:

    def __init__(self, balance):
        self.__balance = balance  # name mangling

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print("Amount deposited successfully")

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
            print("Amount withdrawn successfully")
        else:
            print("Insufficient balance")

    def check_balance(self):
        print("Current balance:", self.__balance)

# %%
bank = BankAccount(1000)

# %%
bank.check_balance()
# Out:
# Current balance: 1000

# %%
bank.deposit(9000)
# Out:
# Amount deposited successfully

# %%
bank.check_balance()
# Out:
# Current balance: 10000

# %%
bank.withdraw(4000)
# Out:
# Amount withdrawn successfully

# %%
bank.check_balance()
# Out:
# Current balance: 6000

# %%
bank.withdraw(8000)
# Out:
# Insufficient balance

# %%
class BankAccount:

    def __init__(self, name, balance):
        self.name = name
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print("Deposit successful")
        else:
            print("Invalid amount")

    def withdraw(self, amount):
        if amount > 0 and amount <= self.__balance:
            self.__balance -= amount
            print("Withdrawal successful")
        else:
            print("Invalid withdrawal")

    def get_balance(self):
        return self.__balance

# %%
bank = BankAccount("rohit", 10000)

# %%
bank.name
# Out:
# 'rohit'

# %%
bank.get_balance()
# Out:
# 10000

# %%
bank.withdraw(-8800)
# Out:
# Invalid withdrawal

# %%
bank.deposit(10000)
# Out:
# Deposit successful

# %%
bank.get_balance()
# Out:
# 20000

# %%
class PhonePe:
    def pay(self):
        print("Payment made through PhonePe.")

class GooglePay:
    def pay(self):
        print("Payment made through Google Pay.")

class Paytm:
    def pay(self):
        print("Payment made through Paytm.")

# %%
apps = [PhonePe(), GooglePay(), Paytm()]

# %%
for app in apps:
    if app == PhonePe():
        print(app.pay())

# %%
for app in apps:
    app.pay()
# Out:
# Payment made through PhonePe.
# Payment made through Google Pay.
# Payment made through Paytm.

# %%
class Calculator:

    def add(self, a, b=0, c=0):
        return a + b + c


calc = Calculator()

print(calc.add(10, 20))
print(calc.add(10, 20, 30))
# Out:
# 30
# 60

# %%
# Duck typing

# %%
class Dog:
    def speak(self):
        print("Dog says Woof")


class Cat:
    def speak(self):
        print("Cat says Meow")

# %%
def make_sound(animal):
    animal.speak()

# %%
make_sound(Dog())
# Out:
# Dog says Woof

# %%
make_sound(Cat())
# Out:
# Cat says Meow
