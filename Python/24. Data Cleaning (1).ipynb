# %%
import pandas as pd

# %%
df1 = pd.read_csv("22. messy_sales_data.csv")

# %%
df = df1.copy()

# %%
df['City'].unique()
# Out:
# <StringArray>
# [ 'bangalore',      'DELHI',    'chennai',    'Jaipur ',    'Amdavad',
#   'New Delhi',  'new delhi',    'Kolkata',  'hyderabad',     'mumbai',
#    ' Lucknow',    'LUCKNOW',     'jaipur',  'Bengaluru',   'Calcutta',
#      'MADRAS',  'bengaluru',     'Bombay',      'Poona',    'CHENNAI',
#        'pune',   'CALCUTTA',    'Lucknow',    'kolkata',  'AHMEDABAD',
#     ' Mumbai',  'Ahmedabad',       'PUNE',     'Jaipur',      'delhi',
#     'KOLKATA',     'Mumbai',          nan,    ' Delhi ',  'HYDERABAD',
#    'calcutta',     'bombay',    'amdavad',  'NEW DELHI',     'JAIPUR',
#   'ahmedabad',      'poona',     'Madras',  'Bangalore',    'Chennai',
#     'lucknow',   'Banglore',     'madras',  'BANGALORE',   'mumbai  ',
#   'Hyderabad',     'BOMBAY',       'Pune',      'Delhi',   'banglore',
#  ' Hyderabad',     'MUMBAI']
# Length: 57, dtype: str

# %%
df['City']= df['City'].str.strip().str.lower()

# %%
df['City'].unique()
# Out:
# <StringArray>
# ['bangalore',     'delhi',   'chennai',    'jaipur',   'amdavad', 'new delhi',
#    'kolkata', 'hyderabad',    'mumbai',   'lucknow', 'bengaluru',  'calcutta',
#     'madras',    'bombay',     'poona',      'pune', 'ahmedabad',         nan,
#   'banglore']
# Length: 19, dtype: str

# %%
city_map = {
    'mumbai': 'Mumbai', 'bombay': 'Mumbai',
    'delhi': 'Delhi', 'new delhi': 'Delhi',
    'bangalore': 'Bangalore', 'bengaluru': 'Bangalore', 'banglore': 'Bangalore',
    'chennai': 'Chennai', 'madras': 'Chennai',
    'kolkata': 'Kolkata', 'calcutta': 'Kolkata',
    'hyderabad': 'Hyderabad',
    'pune': 'Pune', 'poona': 'Pune',
    'ahmedabad': 'Ahmedabad', 'amdavad': 'Ahmedabad',
    'jaipur': 'Jaipur',
    'lucknow': 'Lucknow',
    'unknown': 'Unknown'
}

# %%
df['City']= df['City'].map(city_map).fillna(df["City"].str.title())

# %%
df['City'].unique()
# Out:
# <StringArray>
# ['Bangalore',     'Delhi',   'Chennai',    'Jaipur', 'Ahmedabad',   'Kolkata',
#  'Hyderabad',    'Mumbai',   'Lucknow',      'Pune',         nan]
# Length: 11, dtype: str

# %%
df["City"].isnull().sum()
# Out:
# np.int64(2094)

# %%
df["City"].mode()
# Out:
# 0    Chennai
# Name: City, dtype: str

# %%
df["City"] = df["City"].fillna(df["City"].mode())

# %%
df["City"].isnull().sum()
# Out:
# np.int64(2094)

# %%
df["City"].unique()
# Out:
# <StringArray>
# ['Bangalore',     'Delhi',   'Chennai',    'Jaipur', 'Ahmedabad',   'Kolkata',
#  'Hyderabad',    'Mumbai',   'Lucknow',      'Pune',         nan]
# Length: 11, dtype: str

# %%
df["City"] = df["City"].fillna('Chennai')

# %%
df["City"].unique()
# Out:
# <StringArray>
# ['Bangalore',     'Delhi',   'Chennai',    'Jaipur', 'Ahmedabad',   'Kolkata',
#  'Hyderabad',    'Mumbai',   'Lucknow',      'Pune']
# Length: 10, dtype: str

# %%
df["City"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["City"].unique()
# Out:
# <StringArray>
# ['Bangalore',     'Delhi',   'Chennai',    'Jaipur', 'Ahmedabad',   'Kolkata',
#  'Hyderabad',    'Mumbai',   'Lucknow',      'Pune']
# Length: 10, dtype: str

# %%
df["Category"].unique()
# Out:
# <StringArray>
# [    'Grocery',      'SPORTS',  'electronic',    'Clothing',   'FURNITURE',
#     'CLOTHING',      'BEAUTY',  'Furnitures',   'Clothings', 'electronics',
#       'Beauty',        'TOYS',      'sports',      'beauty',     'grocery',
#         'Book',      'Sports',   'Groceries', 'Electronics',        'book',
#        'Books',     'GROCERY',   'Clothing ',       'books',   'furniture',
#  'ELECTRONICS',   'Furniture',    'clothing',        'Toys',  'Electronic',
#         'toys',         'Toy',       'BOOKS',         'toy',       'Sport']
# Length: 35, dtype: str

# %%
df.columns
# Out:
# Index(['OrderID', 'CustomerID', 'CustomerName', 'City', 'Category',
#        'PaymentMode', 'Price', 'Quantity', 'DiscountPct', 'Rating',
#        'OrderDate', 'CustomerAge', 'Email', 'Phone', 'ReviewText'],
#       dtype='str')

# %%
for col in df.columns:
    print()
    print( f"------------------column name {col}------------------")
    print(df[col].unique())
    print("==="*30)
    print()
# Out:
# ------------------column name OrderID------------------
# <StringArray>
# [ 'ORD51058',  'ORD70248',  'ORD43804',  'ORD46367',  'ORD32922',  'ORD24549',
#   'ORD33523',   'ORD5745',  'ORD89157',  'ORD59831',
#  ...
#   'ORD85628',  'ORD12262',  'ORD26366', 'ORD105705',  'ORD92081',  'ORD49057',
#   'ORD60012',  'ORD78050',  'ORD68225',  'ORD72531']
# Length: 105000, dtype: str
# ==========================================================================================
#
#
# ------------------column name CustomerID------------------
# <StringArray>
# ['CUST04879', 'CUST00177', 'CUST04537', 'CUST07605', 'CUST03180', 'CUST07636',
#  'CUST02017', 'CUST05552', 'CUST06968', 'CUST07512',
#  ...
#  'CUST07495', 'CUST08950', 'CUST02673', 'CUST07007', 'CUST07783', 'CUST05401',
#  'CUST03113', 'CUST00727', 'CUST03384', 'CUST07869']
# Length: 9000, dtype: str
# ==========================================================================================
#
#
# ------------------column name CustomerName------------------
# <StringArray>
# [      'Chaitanya Mane',        'Siddharth Sha', 'Nathaniel Chatterjee',
#     'pranit contractor',   'Hemang Chakraborty',      '  Ishaan Nair  ',
#       ' Tara Nagarajan',          'Waida Kapur',      '  Turvi Dugar  ',
#           'Kevin Amble',
#  ...
#      'banjeet srinivas',       ' GAUTAM SAVANT',   '  frederick lata  ',
#          'SHIVANI BERA',         'indira lanka',       'CHAAYA SOLANKI',
#        'anya deshpande',           ' Jack Dara',           'ATHARV LAD',
#            '  MAX OM  ']
# Length: 37440, dtype: str
# ==========================================================================================
#
#
# ------------------column name City------------------
# <StringArray>
# ['Bangalore',     'Delhi',   'Chennai',    'Jaipur', 'Ahmedabad',   'Kolkata',
#  'Hyderabad',    'Mumbai',   'Lucknow',      'Pune']
# Length: 10, dtype: str
# ==========================================================================================
#
#
# ------------------column name Category------------------
# <StringArray>
# [    'Grocery',      'SPORTS',  'electronic',    'Clothing',   'FURNITURE',
#     'CLOTHING',      'BEAUTY',  'Furnitures',   'Clothings', 'electronics',
#       'Beauty',        'TOYS',      'sports',      'beauty',     'grocery',
#         'Book',      'Sports',   'Groceries', 'Electronics',        'book',
#        'Books',     'GROCERY',   'Clothing ',       'books',   'furniture',
#  'ELECTRONICS',   'Furniture',    'clothing',        'Toys',  'Electronic',
#         'toys',         'Toy',       'BOOKS',         'toy',       'Sport']
# Length: 35, dtype: str
# ==========================================================================================
#
#
# ------------------column name PaymentMode------------------
# <StringArray>
# [     'net_banking',      'Net Banking',              'Upi',
#               'COD',               'cc',       'Debit Card',
#       'credit_card', 'Cash on Delivery',      'net banking',
#       'NET BANKING',                nan,               'dc',
#  'cash on delivery',      'Credit Card',               'DC',
#       'CREDIT CARD',       'Netbanking',       'DEBIT CARD',
#              'UPI ',       'debit card',              'cod',
#               'UPI',              'upi',               'CC',
#       'credit card']
# Length: 25, dtype: str
# ==========================================================================================
#
#
# ------------------column name Price------------------
# <StringArray>
# [    '904.48',    '1823.76',     '770.67',    '2028.06',     '604.00',
#     '1271.25',    '1349.31',   '-1197.45',     '609.16',    '₹876.46',
#  ...
#      '279.18',  '₹1,256.77',     '995.12',    '1208.60',     '526.46',
#     '-767.46',    '1048.24',  '₹1,854.93', 'Rs.1961.37', 'Rs.1468.22']
# Length: 88579, dtype: str
# ==========================================================================================
#
#
# ------------------column name Quantity------------------
# [ 3.  4.  1.  2. -2.  5. -5. -1. -3. -4.]
# ==========================================================================================
#
#
# ------------------column name DiscountPct------------------
# [10 20  0  5 25 15]
# ==========================================================================================
#
#
# ------------------column name Rating------------------
# [3.3 5.  4.9 2.9 3.7 2.8 nan 2.4 1.1 1.9 4.5 1.8 3.2 1.7 3.4 3.  2.1 4.8
#  3.1 3.5 3.6 1.6 2.2 0.5 3.9 1.3 4.1 4.  1.4 2.6 4.4 4.6 4.7 4.3 2.5 2.3
#  5.6 0.8 2.  1.5 7.8 3.8 0.7 2.7 0.9 4.2 1.2 9.4 9.3 8.  0.6 8.9 1.  8.1
#  7.6 9.6 6.8 7.1 8.3 5.8 5.5 7.  7.9 6.4 9.2 8.2 8.7 8.5 7.7 6.1 9.5 7.3
#  6.2 9.8 7.2 5.9 9.9 5.7 9.  6.7 6.5 6.6 6.  8.6 6.3 7.5 9.1 8.8 9.7 8.4
#  6.9 7.4]
# ==========================================================================================
#
#
# ------------------column name OrderDate------------------
# <StringArray>
# [ '2023-04-24',  '04-01-2023',  '11/17/2024',           nan, '14 Jan 2023',
#   '03/26/2023',  '12-12-2023', '11 Dec 2024',  '03/24/2024',  '09/11/2023',
#  ...
#  '21 Nov 2024',  '15/08/2024', '25 Jan 2024',  '24/07/2024',  '2023-10-30',
#   '2024-02-04',  '11/14/2024',  '2024-05-30', '30 Jul 2024',  '2024-12-19']
# Length: 3368, dtype: str
# ==========================================================================================
#
#
# ------------------column name CustomerAge------------------
# [ 29.  38.  40.  41.  44.  32.  34.  43.  36.  69.  42.  56.  22.  39.
#  133.  37.  26.  30.  35.  46.  31.  48.  49.  18.  47.  50.  53.  57.
#   54.  23. 139.  45.  64.  51.   8.  25.  55.  27.  60.  24. 120.  52.
#    0.  28.  63.  58.   5.  59.  21.  20.  66.  70.  19.  33. 150.  62.
#   65.  68. 105.  61.  67.  73.  75.  72.  71.  74.]
# ==========================================================================================
#
#
# ------------------column name Email------------------
# <StringArray>
# [        'chaitanya.mane@gmail.com',                                nan,
#  'nathaniel.chatterjee@outlook.com', 'pranit.contractor@rediffmail.com',
#    'hemang.chakraborty@outlook.com',         'tara.nagarajan@yahoo.com',
#           'waida.kapur@outlook.com',            'turvi.dugar@yahoo.com',
#             'kevin.amble@gmail.com',    'zilmil.pradhan@rediffmail.com',
#  ...
#             'fitan.gupta@gmail.com',         'raagini.gala@outlook.com',
#         'shivani.rastogi@yahoo.com',           'varsha.raj@hotmail.com',
#            'janaki.dugar@yahoo.com',      'gayathri.parikh@hotmail.com',
#          'shivani.bera@hotmail.com',        'mahika.jha@rediffmail.com',
#          'ekiya.kar@rediffmail.com',     'kevin.gokhale@rediffmail.com']
# Length: 39351, dtype: str
# ==========================================================================================
#
#
# ------------------column name Phone------------------
# <StringArray>
# [    '9454663439',              nan,     '9573975601',     '9235766629',
#      '9731250657',     '9755091854',     '9759730420',     '9141381274',
#      '9635764964',     '9810381180',
#  ...
#      '9865735790', '+91-9462435337',     '9811833513',     '9913054504',
#      '9486328773',     '9123457578',     '9226831132',     '9758098090',
#      '9914721436',     '9438589142']
# Length: 96654, dtype: str
# ==========================================================================================
#
#
# ------------------column name ReviewText------------------
# <StringArray>
# [                       'Packaging was bad',
#                         '  great service  ',
#                           'Okayish product',
#                                         nan,
#                   'Superb!!! fast delivery',
#                         'delivery was late',
#  'worst product ever received damaged item',
#                        'Average experience',
#               'Not satisfied  poor quality',
#                           'value for money',
#                     'Good product loved it',
#               'Excellent!!! will buy again',
#                        'Will not recommend',
#                      'Product as described',
#                        'Amazing quality!!!']
# Length: 15, dtype: str
# ==========================================================================================

# %%
df['Category'].unique()
# Out:
# <StringArray>
# [    'Grocery',      'SPORTS',  'electronic',    'Clothing',   'FURNITURE',
#     'CLOTHING',      'BEAUTY',  'Furnitures',   'Clothings', 'electronics',
#       'Beauty',        'TOYS',      'sports',      'beauty',     'grocery',
#         'Book',      'Sports',   'Groceries', 'Electronics',        'book',
#        'Books',     'GROCERY',   'Clothing ',       'books',   'furniture',
#  'ELECTRONICS',   'Furniture',    'clothing',        'Toys',  'Electronic',
#         'toys',         'Toy',       'BOOKS',         'toy',       'Sport']
# Length: 35, dtype: str

# %%
df['Category'] = df['Category'].str.strip().str.lower().str.rstrip("s")

# %%
df['Category'].unique()
# Out:
# <StringArray>
# [   'grocery',      'sport', 'electronic',   'clothing',  'furniture',
#      'beauty',        'toy',       'book',   'grocerie']
# Length: 9, dtype: str

# %%
df['Category'] = df['Category'].str.replace('grocerie','grocery' )

# %%
df['Category'].unique()
# Out:
# <StringArray>
# [   'grocery',      'sport', 'electronic',   'clothing',  'furniture',
#      'beauty',        'toy',       'book']
# Length: 8, dtype: str

# %%
df['Category'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Category'] = df['Category'].str.title()
df['Category'].unique()
# Out:
# <StringArray>
# [   'Grocery',      'Sport', 'Electronic',   'Clothing',  'Furniture',
#      'Beauty',        'Toy',       'Book']
# Length: 8, dtype: str

# %%
df['PaymentMode'].unique()
# Out:
# <StringArray>
# [     'net_banking',      'Net Banking',              'Upi',
#               'COD',               'cc',       'Debit Card',
#       'credit_card', 'Cash on Delivery',      'net banking',
#       'NET BANKING',                nan,               'dc',
#  'cash on delivery',      'Credit Card',               'DC',
#       'CREDIT CARD',       'Netbanking',       'DEBIT CARD',
#              'UPI ',       'debit card',              'cod',
#               'UPI',              'upi',               'CC',
#       'credit card']
# Length: 25, dtype: str

# %%
payment_map = {
    'credit card':'Credit Card', 'cc':'Credit Card', 'credit_card':'Credit Card',
    'debit card':'Debit Card', 'dc':'Debit Card',
    'upi':'UPI',
    'cod':'Cash on Delivery', 'cash on delivery':'Cash on Delivery',
    'net banking':'Net Banking', 'netbanking':'Net Banking', 'net_banking':'Net Banking'
}

# %%
df['PaymentMode'] = df['PaymentMode'].str.strip().str.lower().map(payment_map)

# %%
df['PaymentMode'].unique()
# Out:
# <StringArray>
# ['Net Banking', 'UPI', 'Cash on Delivery', 'Credit Card', 'Debit Card', nan]
# Length: 6, dtype: str

# %%
df['PaymentMode'].isnull().sum()
# Out:
# np.int64(3243)

# %%
df['PaymentMode'].mode()[0]
# Out:
# 'Net Banking'

# %%
df['PaymentMode']= df['PaymentMode'].fillna(df['PaymentMode'].mode()[0])

# %%
df['PaymentMode'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Price'].unique()
# Out:
# <StringArray>
# [    '904.48',    '1823.76',     '770.67',    '2028.06',     '604.00',
#     '1271.25',    '1349.31',   '-1197.45',     '609.16',    '₹876.46',
#  ...
#      '279.18',  '₹1,256.77',     '995.12',    '1208.60',     '526.46',
#     '-767.46',    '1048.24',  '₹1,854.93', 'Rs.1961.37', 'Rs.1468.22']
# Length: 88579, dtype: str

# %%
type(df['Price'])
# Out:
# pandas.Series

# %%
df['Price'].dtypes
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df["Price"].astype("int")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 df["Price"].astype("int")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# --> 611     return self.apply("astype", dtype=dtype, errors=errors)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:442, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440         applied = b.apply(f, **kwargs)
#     441     else:
# --> 442         applied = getattr(b, f)(**kwargs)
#     443     result_blocks = extend_blocks(applied, result_blocks)
#     445 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:607, in Block.astype(self, dtype, errors, squeeze)
#     604         raise ValueError("Can not squeeze with more than one column.")
#     605     values = values[0, :]  # type: ignore[call-overload]
# --> 607 new_values = astype_array_safe(values, dtype, errors=errors)
#     609 new_values = maybe_coerce_values(new_values)
#     611 refs = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:240, in astype_array_safe(values, dtype, copy, errors)
#     237     dtype = dtype.numpy_dtype
#     239 try:
# --> 240     new_values = astype_array(values, dtype, copy=copy)
#     241 except (ValueError, TypeError):
#     242     # e.g. _astype_nansafe can fail on object-dtype of strings
#     243     #  trying to convert to float
#     244     if errors == "ignore":
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     178     return values
#     180 if not isinstance(values, np.ndarray):
#     181     # i.e. ExtensionArray
# --> 182     values = values.astype(dtype, copy=copy)
#     184 else:
#     185     values = _astype_nansafe(values, dtype, copy=copy)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arrays\string_.py:944, in StringArray.astype(self, dtype, copy)
#     941     values[mask] = np.nan
#     942     return values
# --> 944 return super().astype(dtype, copy)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arrays\numpy_.py:280, in NumpyExtensionArray.astype(self, dtype, copy)
#     277         return self.copy()
#     278     return self
# --> 280 result = astype_array(self._ndarray, dtype=dtype, copy=copy)
#     281 return result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:185, in astype_array(values, dtype, copy)
#     182     values = values.astype(dtype, copy=copy)
#     184 else:
# --> 185     values = _astype_nansafe(values, dtype, copy=copy)
#     187 # in pandas we don't store numpy str dtypes, so convert to object
#     188 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or object in (arr.dtype, dtype):
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '904.48'

# %%
df["Price"] = df["Price"].str.strip().str.replace("₹", "")

# %%
df["Price"].unique()
# Out:
# <StringArray>
# [    '904.48',    '1823.76',     '770.67',    '2028.06',     '604.00',
#     '1271.25',    '1349.31',   '-1197.45',     '609.16',     '876.46',
#  ...
#      '279.18',   '1,256.77',     '995.12',    '1208.60',     '526.46',
#     '-767.46',    '1048.24',   '1,854.93', 'Rs.1961.37', 'Rs.1468.22']
# Length: 86761, dtype: str

# %%
df["Price"] = df["Price"].str.replace("Rs.", "")

# %%
df["Price"].unique()
# Out:
# <StringArray>
# [  '904.48',  '1823.76',   '770.67',  '2028.06',   '604.00',  '1271.25',
#   '1349.31', '-1197.45',   '609.16',   '876.46',
#  ...
#    '279.18', '1,256.77',   '995.12',  '1208.60',   '526.46',  '-767.46',
#   '1048.24', '1,854.93',  '1961.37',  '1468.22']
# Length: 84495, dtype: str

# %%
df["Price"] = df["Price"].str.replace("-", "")

# %%
df["Price"].unique()
# Out:
# <StringArray>
# [  '904.48',  '1823.76',   '770.67',  '2028.06',   '604.00',  '1271.25',
#   '1349.31',  '1197.45',   '609.16',   '876.46',
#  ...
#    '977.41',   '279.18', '1,256.77',   '995.12',  '1208.60',   '526.46',
#   '1048.24', '1,854.93',  '1961.37',  '1468.22']
# Length: 82951, dtype: str

# %%
df["Price"].dtypes
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df["Price"] = df["Price"].str.replace(",", "")

# %%
df["Price"] = df["Price"].astype("float64")

# %%
df.dtypes
# Out:
# OrderID             str
# CustomerID          str
# CustomerName        str
# City                str
# Category            str
# PaymentMode         str
# Price           float64
# Quantity        float64
# DiscountPct       int64
# Rating          float64
# OrderDate           str
# CustomerAge     float64
# Email               str
# Phone               str
# ReviewText          str
# dtype: object

# %%
df["Quantity"].unique()
# Out:
# array([ 3.,  4.,  1.,  2., -2.,  5., -5., -1., -3., -4.])

# %%
df["Quantity"] = df["Quantity"].abs()

# %%
df["Quantity"].unique()
# Out:
# array([3., 4., 1., 2., 5.])

# %%
df["Quantity"] = df["Quantity"].astype("int64")

# %%
df['Rating']
# Out:
# 0         3.3
# 1         5.0
# 2         4.9
# 3         2.9
# 4         3.7
#          ...
# 106570    5.0
# 106571    3.3
# 106572    3.3
# 106573    4.6
# 106574    4.3
# Name: Rating, Length: 106575, dtype: float64

# %%
df['Rating'].describe()
# Out:
# count    100129.000000
# mean          3.409874
# std           1.306731
# min           0.500000
# 25%           2.600000
# 50%           3.300000
# 75%           4.100000
# max           9.900000
# Name: Rating, dtype: float64

# %%
df['Rating'].unique()
# Out:
# array([3.3, 5. , 4.9, 2.9, 3.7, 2.8, nan, 2.4, 1.1, 1.9, 4.5, 1.8, 3.2,
#        1.7, 3.4, 3. , 2.1, 4.8, 3.1, 3.5, 3.6, 1.6, 2.2, 0.5, 3.9, 1.3,
#        4.1, 4. , 1.4, 2.6, 4.4, 4.6, 4.7, 4.3, 2.5, 2.3, 5.6, 0.8, 2. ,
#        1.5, 7.8, 3.8, 0.7, 2.7, 0.9, 4.2, 1.2, 9.4, 9.3, 8. , 0.6, 8.9,
#        1. , 8.1, 7.6, 9.6, 6.8, 7.1, 8.3, 5.8, 5.5, 7. , 7.9, 6.4, 9.2,
#        8.2, 8.7, 8.5, 7.7, 6.1, 9.5, 7.3, 6.2, 9.8, 7.2, 5.9, 9.9, 5.7,
#        9. , 6.7, 6.5, 6.6, 6. , 8.6, 6.3, 7.5, 9.1, 8.8, 9.7, 8.4, 6.9,
#        7.4])

# %%
df['Rating'] = pd.to_numeric(df['Rating'],errors= 'coerce')

# %%
df['Rating'].unique()
# Out:
# array([3.3, 5. , 4.9, 2.9, 3.7, 2.8, nan, 2.4, 1.1, 1.9, 4.5, 1.8, 3.2,
#        1.7, 3.4, 3. , 2.1, 4.8, 3.1, 3.5, 3.6, 1.6, 2.2, 0.5, 3.9, 1.3,
#        4.1, 4. , 1.4, 2.6, 4.4, 4.6, 4.7, 4.3, 2.5, 2.3, 5.6, 0.8, 2. ,
#        1.5, 7.8, 3.8, 0.7, 2.7, 0.9, 4.2, 1.2, 9.4, 9.3, 8. , 0.6, 8.9,
#        1. , 8.1, 7.6, 9.6, 6.8, 7.1, 8.3, 5.8, 5.5, 7. , 7.9, 6.4, 9.2,
#        8.2, 8.7, 8.5, 7.7, 6.1, 9.5, 7.3, 6.2, 9.8, 7.2, 5.9, 9.9, 5.7,
#        9. , 6.7, 6.5, 6.6, 6. , 8.6, 6.3, 7.5, 9.1, 8.8, 9.7, 8.4, 6.9,
#        7.4])

# %%
(df['Rating'] < 0 )
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106570    False
# 106571    False
# 106572    False
# 106573    False
# 106574    False
# Name: Rating, Length: 106575, dtype: bool

# %%
(df['Rating'] > 5)

# %%
df.head()
# Out:
#     OrderID CustomerID          CustomerName       City    Category  \
# 0  ORD51058  CUST04879        Chaitanya Mane  Bangalore     Grocery
# 1  ORD70248  CUST00177         Siddharth Sha      Delhi       Sport
# 2  ORD43804  CUST04537  Nathaniel Chatterjee    Chennai  Electronic
# 3  ORD46367  CUST07605     pranit contractor     Jaipur    Clothing
# 4  ORD32922  CUST03180    Hemang Chakraborty  Ahmedabad   Furniture
#
#         PaymentMode    Price  Quantity  DiscountPct  Rating    OrderDate  \
# 0       Net Banking   904.48         3           10     3.3   2023-04-24
# 1       Net Banking  1823.76         4           20     5.0   04-01-2023
# 2               UPI   770.67         1            0     4.9   11/17/2024
# 3  Cash on Delivery  2028.06         1            0     2.9          NaN
# 4       Credit Card   604.00         4           10     3.7  14 Jan 2023
#
#    CustomerAge                             Email       Phone  \
# 0         29.0          chaitanya.mane@gmail.com  9454663439
# 1         38.0                               NaN         NaN
# 2         40.0  nathaniel.chatterjee@outlook.com  9573975601
# 3         41.0  pranit.contractor@rediffmail.com  9235766629
# 4         44.0    hemang.chakraborty@outlook.com  9731250657
#
#                 ReviewText
# 0        Packaging was bad
# 1          great service
# 2          Okayish product
# 3                      NaN
# 4  Superb!!! fast delivery

# %%
df.loc[0:100000:10000,["City", "Price", "OrderID"]]
# Out:
#              City    Price   OrderID
# 0       Bangalore   904.48  ORD51058
# 10000   Hyderabad  1163.12   ORD5068
# 20000   Hyderabad   515.60  ORD94030
# 30000       Delhi   405.97  ORD92683
# 40000   Bangalore  1377.23  ORD84537
# 50000       Delhi  1457.76  ORD94939
# 60000     Kolkata   633.14  ORD54005
# 70000     Chennai  1554.58  ORD52725
# 80000     Lucknow  1063.18   ORD4063
# 90000     Chennai   503.94  ORD12862
# 100000  Hyderabad  1407.61  ORD48867

# %%
df.iloc[0::5000, 0::3]
# Out:
#          OrderID       City    Price  Rating                          Email
# 0       ORD51058  Bangalore   904.48     3.3       chaitanya.mane@gmail.com
# 5000    ORD79486       Pune   704.69     3.5   yashawini.raj@rediffmail.com
# 10000    ORD5068  Hyderabad  1163.12     1.3   krishna.morar@rediffmail.com
# 15000   ORD75165  Bangalore  1098.29     3.4       bhavani.devi@hotmail.com
# 20000   ORD94030  Hyderabad   515.60     3.4       elijah.mitra@hotmail.com
# 25000   ORD46339    Kolkata  1207.32     3.6       anmol.chadha@outlook.com
# 30000   ORD92683      Delhi   405.97     2.2           jhalak.rau@yahoo.com
# 35000   ORD41431       Pune   398.51     4.0       chaman.lalla@hotmail.com
# 40000   ORD84537  Bangalore  1377.23     3.6                            NaN
# 45000   ORD78382  Bangalore  5539.55     1.6         arya.shere@outlook.com
# 50000   ORD94939      Delhi  1457.76     3.6   hemangini.pandey@hotmail.com
# 55000   ORD12839       Pune  1365.90     1.5      pavani.chandran@gmail.com
# 60000   ORD54005    Kolkata   633.14     1.7     jalsa.saraf@rediffmail.com
# 65000   ORD28880    Chennai   750.81     3.8       unnati.jaggi@hotmail.com
# 70000   ORD52725    Chennai  1554.58     4.0  gautam.shankar@rediffmail.com
# 75000   ORD93926    Kolkata  1260.75     1.1    quincy.malhotra@hotmail.com
# 80000    ORD4063    Lucknow  1063.18     4.4     harrison.varma@outlook.com
# 85000   ORD35778     Jaipur   467.83     2.8           nitesh.lad@yahoo.com
# 90000   ORD12862    Chennai   503.94     3.3      kavya.dhillon@hotmail.com
# 95000   ORD97741    Kolkata   546.72     2.4        indrajit.gala@gmail.com
# 100000  ORD48867  Hyderabad  1407.61     4.7       alka.peri@rediffmail.com
# 105000  ORD61902    Kolkata  1090.48     3.5         yash.sawhney@gmail.com

# %%
df.loc[0:100000:10000,0::2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 df.loc[0:100000:10000,0::2]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1200, in _LocationIndexer.__getitem__(self, key)
#    1198     if self._is_scalar_access(key):
#    1199         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#    1203     axis = self.axis or 0
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1395, in _LocIndexer._getitem_tuple(self, tup)
#    1392 if self._multi_take_opportunity(tup):
#    1393     return self._multi_take(tup)
# -> 1395 return self._getitem_tuple_same_dim(tup)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1046, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#    1043 if com.is_null_slice(key):
#    1044     continue
# -> 1046 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1047 # We should never have retval.ndim < self.ndim, as that should
#    1048 #  be handled by the _getitem_lowerdim call above.
#    1049 assert retval.ndim == self.ndim
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1429, in _LocIndexer._getitem_axis(self, key, axis)
#    1427 if isinstance(key, slice):
#    1428     self._validate_key(key, axis)
# -> 1429     return self._get_slice_axis(key, axis=axis)
#    1430 elif com.is_bool_indexer(key):
#    1431     return self._getbool_axis(key, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1461, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1458     return obj.copy(deep=False)
#    1460 labels = obj._get_axis(axis)
# -> 1461 indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1463 if isinstance(indexer, slice):
#    1464     return self.obj._slice(indexer, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6804, in Index.slice_indexer(self, start, end, step)
#    6753 def slice_indexer(
#    6754     self,
#    6755     start: Hashable | None = None,
#    6756     end: Hashable | None = None,
#    6757     step: int | None = None,
#    6758 ) -> slice:
#    6759     """
#    6760     Compute the slice indexer for input labels and step.
#    6761
#    (...)   6802     slice(1, 3, None)
#    6803     """
# -> 6804     start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6806     # return a slice
#    6807     if not is_scalar(start_slice):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:7062, in Index.slice_locs(self, start, end, step)
#    7060 start_slice = None
#    7061 if start is not None:
# -> 7062     start_slice = self.get_slice_bound(start, "left")
#    7063 if start_slice is None:
#    7064     start_slice = 0
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6964, in Index.get_slice_bound(self, label, side)
#    6960 original_label = label
#    6962 # For datetime indices label may be a string that has to be converted
#    6963 # to datetime boundary according to its resolution.
# -> 6964 label = self._maybe_cast_slice_bound(label, side)
#    6966 # we need to look up the label
#    6967 try:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6894, in Index._maybe_cast_slice_bound(self, label, side)
#    6892 # reject them, if index does not contain label
#    6893 if (is_float(label) or is_integer(label)) and label not in self:
# -> 6894     self._raise_invalid_indexer("slice", label)
#    6896 return label
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:4125, in Index._raise_invalid_indexer(self, form, key, reraise)
#    4123 if reraise is not lib.no_default:
#    4124     raise TypeError(msg) from reraise
# -> 4125 raise TypeError(msg)
#
# TypeError: cannot do slice indexing on Index with these indexers [0] of type int
