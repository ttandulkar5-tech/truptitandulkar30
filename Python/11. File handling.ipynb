# %% [raw]
# mode
# w
# r
# a
# r+

# %%
f  = open("test.txt", "w")

# %%
f.write("this is my first")
# Out:
# 16

# %%
f.close()

# %%
f = open("test.txt", "r")

# %%
f.read()
# Out:
# 'this is my first'

# %%
f.close()

# %%
f = open("test.txt", "r+")

# %%
f.read()
# Out:
# 'this is my first'

# %%
f.write(" new content added")
# Out:
# 18

# %%
f.close()

# %%
f  =open("test.txt", "w")

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 f.read()
#
# UnsupportedOperation: not readable

# %%
f.write("UnsupportedOperation: not readable")
# Out:
# 34

# %%
f.close()

# %%
f = open("test.txt", "a")

# %%
f.write("   hello")
# Out:
# 8

# %%
f.close()

# %%
with open("test.txt", "r") as f:
    print(f.read())
    f.close()
# Out:
# UnsupportedOperation: not readable   hello

# %%
# %%writefile dmeo.txt
# hello this is python
# Out:
# Writing dmeo.txt

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'dmeo.txt',
#  'test.txt',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled10.ipynb',
#  'Untitled11.ipynb',
#  'Untitled12.ipynb',
#  'Untitled13.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  'Untitled7.ipynb',
#  'Untitled8.ipynb',
#  'Untitled9.ipynb']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\amitm\\Class\\01. X-DSAAI-15'

# %%
os.chdir("C:\\Users\\amitm/Downloads")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\amitm\\Downloads'

# %%
os.listdir()
# Out:
# ['03. basic constraint and view.sql',
#  '09. Loops-1.ipynb',
#  'amitmakode-main.zip',
#  'cloudblitz_ds_student_tool.html',
#  'crm',
#  'Data Analytics.jpg',
#  'day1-session cdec.html',
#  'day26_sql_functions.sql',
#  'day3-session old.html',
#  'Deep Learning.jpg',
#  'desktop.ini',
#  'download.jpg',
#  'estate-crm-prototype (1).html',
#  'estate-crm-prototype (2).html',
#  'estate-crm-prototype.html',
#  'GenAI_Mock_Interview_30Q.md',
#  'generate_role_card (1).py',
#  'generate_role_card.py',
#  'how-computers-run-programs.html',
#  'meet-the-terminal-1.html',
#  'meet-the-terminal-2-tool-setup.html',
#  'Module4_Excel_PowerBI_Session_Plan.xlsx',
#  'Module5_AWS_Cloud_Core_Session_Plan.xlsx',
#  'New folder',
#  'online shoppers.csv',
#  'Placement_Master_Tracker (2).xlsx',
#  'platonic_cave.webp',
#  'README.md',
#  'realestate_crm_app.zip',
#  'real_estate_crm_architecture.svg',
#  'role-card (1).yml',
#  'role-card.yml',
#  '~$L_Advanced_Test.docx']

# %%
os.mkdir("newdir")

# %%
os.listdir()
# Out:
# ['03. basic constraint and view.sql',
#  '09. Loops-1.ipynb',
#  'amitmakode-main.zip',
#  'cloudblitz_ds_student_tool.html',
#  'crm',
#  'Data Analytics.jpg',
#  'day1-session cdec.html',
#  'day26_sql_functions.sql',
#  'day3-session old.html',
#  'Deep Learning.jpg',
#  'desktop.ini',
#  'download.jpg',
#  'estate-crm-prototype (1).html',
#  'estate-crm-prototype (2).html',
#  'estate-crm-prototype.html',
#  'GenAI_Mock_Interview_30Q.md',
#  'generate_role_card (1).py',
#  'generate_role_card.py',
#  'how-computers-run-programs.html',
#  'meet-the-terminal-1.html',
#  'meet-the-terminal-2-tool-setup.html',
#  'Module4_Excel_PowerBI_Session_Plan.xlsx',
#  'Module5_AWS_Cloud_Core_Session_Plan.xlsx',
#  'New folder',
#  'newdir',
#  'online shoppers.csv',
#  'Placement_Master_Tracker (2).xlsx',
#  'platonic_cave.webp',
#  'README.md',
#  'realestate_crm_app.zip',
#  'real_estate_crm_architecture.svg',
#  'role-card (1).yml',
#  'role-card.yml',
#  '~$L_Advanced_Test.docx']

# %%
os.chdir("C:\\Users\\amitm/Downloads/newdir")

# %%
os.listdir()
# Out:
# []

# %%
# %%writefile demo.py
print("hello")
# Out:
# Writing demo.py

# %%
os.listdir()
# Out:
# ['demo.py']

# %%
os.remove("demo.py")

# %%
os.listdir()
# Out:
# []

# %%
os.chdir("C:\\Users\\amitm/Downloads")

# %%
os.listdir()
# Out:
# ['03. basic constraint and view.sql',
#  '09. Loops-1.ipynb',
#  'amitmakode-main.zip',
#  'cloudblitz_ds_student_tool.html',
#  'crm',
#  'Data Analytics.jpg',
#  'day1-session cdec.html',
#  'day26_sql_functions.sql',
#  'day3-session old.html',
#  'Deep Learning.jpg',
#  'desktop.ini',
#  'download.jpg',
#  'estate-crm-prototype (1).html',
#  'estate-crm-prototype (2).html',
#  'estate-crm-prototype.html',
#  'GenAI_Mock_Interview_30Q.md',
#  'generate_role_card (1).py',
#  'generate_role_card.py',
#  'how-computers-run-programs.html',
#  'meet-the-terminal-1.html',
#  'meet-the-terminal-2-tool-setup.html',
#  'Module4_Excel_PowerBI_Session_Plan.xlsx',
#  'Module5_AWS_Cloud_Core_Session_Plan.xlsx',
#  'New folder',
#  'newdir',
#  'online shoppers.csv',
#  'Placement_Master_Tracker (2).xlsx',
#  'platonic_cave.webp',
#  'README.md',
#  'realestate_crm_app.zip',
#  'real_estate_crm_architecture.svg',
#  'role-card (1).yml',
#  'role-card.yml',
#  '~$L_Advanced_Test.docx']

# %%
os.rmdir("newdir")

# %%
os.listdir()
# Out:
# ['03. basic constraint and view.sql',
#  '09. Loops-1.ipynb',
#  'amitmakode-main.zip',
#  'cloudblitz_ds_student_tool.html',
#  'crm',
#  'Data Analytics.jpg',
#  'day1-session cdec.html',
#  'day26_sql_functions.sql',
#  'day3-session old.html',
#  'Deep Learning.jpg',
#  'desktop.ini',
#  'download.jpg',
#  'estate-crm-prototype (1).html',
#  'estate-crm-prototype (2).html',
#  'estate-crm-prototype.html',
#  'GenAI_Mock_Interview_30Q.md',
#  'generate_role_card (1).py',
#  'generate_role_card.py',
#  'how-computers-run-programs.html',
#  'meet-the-terminal-1.html',
#  'meet-the-terminal-2-tool-setup.html',
#  'Module4_Excel_PowerBI_Session_Plan.xlsx',
#  'Module5_AWS_Cloud_Core_Session_Plan.xlsx',
#  'New folder',
#  'online shoppers.csv',
#  'Placement_Master_Tracker (2).xlsx',
#  'platonic_cave.webp',
#  'README.md',
#  'realestate_crm_app.zip',
#  'real_estate_crm_architecture.svg',
#  'role-card (1).yml',
#  'role-card.yml',
#  '~$L_Advanced_Test.docx']

# %%
os.chdir('C:\\Users\\amitm\\Class\\01. X-DSAAI-15')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\amitm\\Class\\01. X-DSAAI-15'

# %%
#relative path

filepath = "demo.txt"
filepath = "download/demo.txt"
filepath = 'amitm\\Downloads\\newfolder'

# %%
# absolute path - full path from root of the file system

filepath = 'C:/Users/amitm/Downloads/newfolder'

# %%
filepath1 = 'C:/Users/amitm/Downloads'
filepath2 = 'newfolder/new.txt'

# %%
os.path.join(filepath1, filepath2)
# Out:
# 'C:/Users/amitm/Downloads\\newfolder/new.txt'

# %%
for i in range(1, 11):
    file_name = f"file_{i}.txt"

    with open(file_name, "w") as file:
        file.write(f"This is File {i}\n")

print("10 files created successfully!")
# Out:
# 10 files created successfully!

# %%
for i in range(1, 11):
    file_name = f"file_{i}.txt"

    if os.path.exists(file_name):
        os.remove(file_name)
        print(f"{file_name} deleted.")
    else:
        print(f"{file_name} not found.")

print("Process completed.")
# Out:
# file_1.txt deleted.
# file_2.txt deleted.
# file_3.txt deleted.
# file_4.txt deleted.
# file_5.txt deleted.
# file_6.txt deleted.
# file_7.txt deleted.
# file_8.txt deleted.
# file_9.txt deleted.
# file_10.txt deleted.
# Process completed.

# %%
with open("student.txt", "w") as file:
    for i in range(1, 11):
        file.write(f"This is line {i}\n")

print("File created successfully.")
# Out:
# File created successfully.

# %%
students = ["Amit", "Rahul", "Priya", "Neha", "Rohit"]

with open("students.txt", "w") as file:
    for student in students:
        file.write(student + "\n")

print("Student names written successfully.")
# Out:
# Student names written successfully.

# %%
for i in range(1, 11):
    with open(f"file_{i}.txt", "w") as file:
        for j in range(1, 6):
            file.write(f"Line {j} of File {i}\n")

print("10 files created with 5 lines each.")
# Out:
# 10 files created with 5 lines each.

# %%
import os

file_name = "student.txt"

if os.path.exists(file_name):
    os.remove(file_name)
    print("File deleted successfully.")
else:
    print("File not found.")
# Out:
# File deleted successfully.

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'dmeo.txt',
#  'file_1.txt',
#  'file_10.txt',
#  'file_2.txt',
#  'file_3.txt',
#  'file_4.txt',
#  'file_5.txt',
#  'file_6.txt',
#  'file_7.txt',
#  'file_8.txt',
#  'file_9.txt',
#  'student.txt',
#  'students.txt',
#  'test.txt',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled10.ipynb',
#  'Untitled11.ipynb',
#  'Untitled12.ipynb',
#  'Untitled13.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  'Untitled7.ipynb',
#  'Untitled8.ipynb',
#  'Untitled9.ipynb']

# %%
for i in range(1, 11):
    file_name = f"file_{i}.txt"

    with open(file_name, "w") as file:
        file.write(f"This is File {i}\n")

print("10 files created successfully!")

# %%
for i in range(1,11):
    file_name = f"file_{i}.txt"
    print(file_name)
# Out:
# file_1.txt
# file_2.txt
# file_3.txt
# file_4.txt
# file_5.txt
# file_6.txt
# file_7.txt
# file_8.txt
# file_9.txt
# file_10.txt

# %%
type(os.listdir())
# Out:
# list

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'dmeo.txt',
#  'file_1.txt',
#  'file_10.txt',
#  'file_2.txt',
#  'file_3.txt',
#  'file_4.txt',
#  'file_5.txt',
#  'file_6.txt',
#  'file_7.txt',
#  'file_8.txt',
#  'file_9.txt',
#  'students.txt',
#  'test.txt',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled10.ipynb',
#  'Untitled11.ipynb',
#  'Untitled12.ipynb',
#  'Untitled13.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  'Untitled7.ipynb',
#  'Untitled8.ipynb',
#  'Untitled9.ipynb']

# %%
for i in os.listdir():
    if i == 'Untitled2.ipynb':
        os.remove(i)
