# %%
def add(num1, num2)-> int:
    """this is my first function
    which use to add two number 
    argument will be intger"""
    return num1+ num2

# %%
add(4, 9)
# Out:
# 13

# %%
def printname()-> str:
    name = input()
    return name

# %%
print()

# %%
printname()
# Out:
#  amit
# 'amit'

# %% [markdown]
# ## OOPs

# %%
class
self
__init__
def
public variable
protected variable
private variable
override method
inheritence
polymorphism
encapsulation
super()
mro()
duck typing
@staticmethod

# %%
class person:

    def __init__ (self, name, profession, dob ):
        self.name = name
        self.profession = profession
        self.dob= dob

# %%
obj = person("rohit", "ca", "1995")

# %%
obj.name
# Out:
# 'rohit'

# %%
obj.dob
# Out:
# '1995'

# %%
obj2 = person("Suraj", "cricketer", "2000")

# %%
obj2.name
# Out:
# 'Suraj'

# %%
obj.name
# Out:
# 'rohit'

# %%
class person:

    def __init__ (self, name, profession, dob ):
        self.name = name
        self.profession = profession
        self.dob= dob

    def __init__ (self, name, profession ):
        self.name = name
        self.profession = profession

    def __init__ (self, name, profession,dob, education ):
        self.name = name
        self.profession = profession
        self.dob=dob
        self.education= education

# %%
obj = person("vikash", "trainer", "1996", "BE")

# %%
obj.education
# Out:
# 'BE'

# %%
class person:

    company = "TCS"

    def __init__ (self, name, profession,dob, education ):
        self.name = name
        self.profession = profession
        self.dob=dob
        self.education= education

# %%
obj = person("vikash", "trainer", "1996", "BE")

# %%
obj.company
# Out:
# 'TCS'

# %%
class person:

    company = "TCS"

    def __init__ (self, name, profession,dob, education ):
        self.name = name
        self.profession = profession
        self.dob=dob
        self.education= education

    def age(self, current_year):
        return current_year - self.dob

# %%
obj = person("vikash", "trainer", 1990, "BE")

# %%
obj.dob
# Out:
# 1990

# %%
obj.age(2026)
# Out:
# 36

# %%
obj.company
# Out:
# 'TCS'

# %%
class person:
    
    company = "TCS"
    
    def __init__ (self, name, profession,dob, education ):
        self.name = name
        self.profession = profession
        self.dob=dob
        self.education= education
        
    def age(self, current_year):
        return current_year - self.dob
        
    def company1(self, new_company):
        self.new_company = new_company
        return new_company

# %%
obj = person("vikash", "trainer", 1990, "BE")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 obj = person("vikash", "trainer", 1990, "BE")
#
# Cell In[58], line 6, in person.__init__(self, name, profession, dob, education)
#       5 def __init__ (self, name, profession,dob, education ):
# ----> 6     self.name = name1
#       7     self.profession = profession
#       8     self.dob=dob1
#
# NameError: name 'name1' is not defined

# %%
obj.company
# Out:
# 'TCS'

# %%
obj.company1("infy")
# Out:
# 'infy'

# %%
obj.dob
# Out:
# 'vikash'

# %%
class Student:
    def __init__(self, name, grade="A", school="Unknown"):
        """Constructor with default parameters"""
        self.name = name
        self.grade = grade
        self.school = school

# %%
obj = Student("rahul")

# %%
obj.school
# Out:
# 'Unknown'

# %%
class PublicExample:
    def __init__(self):
        self.public_var = "I'm public"  # Public attribute
    
    def public_method(self):  # Public method
        return "This is a public method"

# %%
obj = PublicExample()

# %%
obj.public_var
# Out:
# "I'm public"

# %%
obj.public_method()
# Out:
# 'This is a public method'

# %%
class ProtectedExample:

    _company = "TCS"
    
    def __init__(self):
        self._protected_var = "I'm protected"  # Protected attribute
    
    def _protected_method(self):  # Protected method
        return "This is a protected method"
    
    def access_protected(self):
        """Public method to access protected members"""
        return self._protected_var

# %%
obj = ProtectedExample()

# %%
obj._protected_method()
# Out:
# 'This is a protected method'

# %%
obj._company
# Out:
# 'TCS'

# %%
obj._protected_var
# Out:
# "I'm protected"

# %%
class PrivateExample:
    def __init__(self):
        self.__private_var = "I'm private"  # Private attribute
        self.public_var = "I'm public"
    
    def __private_method(self):  # Private method
        return "This is a private method"
    
    def access_private(self):
        """Public method to access private members"""
        return self.__private_var + " - " + self.__private_method()

# %%
obj = PrivateExample()

# %%
obj.access_private()
# Out:
# "I'm private - This is a private method"

# %%
obj._PrivateExample__private_method()
# Out:
# 'This is a private method'

# %%
obj._PrivateExample__private_var
# Out:
# "I'm private"

# %%
class Calculator:

    """hello word"""
    
    def __init__(self, value)->int:
        self._value = value
    
    def add(self, num):  # Instance method
        """Adds number to instance value"""
        self._value += num
        return self._value
    
    def get_value(self):  # Instance method
        """Returns current value"""
        return self._value

# %%
cal = Calculator(1000)

# %%
cal.value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 cal.value
#
# AttributeError: 'Calculator' object has no attribute 'value'

# %%
cal.add(5000)
# Out:
# 6000

# %%
cal.get_value()
# Out:
# 6000

# %%
cal.value
# Out:
# 6000

# %%
class MathUtils:
    
    @staticmethod
    def add(a, b):  # Static method
        """Adds two numbers"""
        return a + b
    
    @staticmethod
    def is_even(num):  # Static method
        """Checks if number is even"""
        return num % 2 == 0
    
    @staticmethod
    def factorial(n):  # Static method
        """Calculates factorial"""
        if n <= 1:
            return 1
        return n * MathUtils.factorial(n - 1)

# %%
math = MathUtils()

# %%
math.factorial(6)
# Out:
# 720
