# %%
import pandas as pd

# %%
df1 = pd.read_csv("C:\\Users\\amitm\\Downloads\\22. messy_sales_data.csv")

# %%
df = df1.copy()

# %%
df.head()
# Out:
#     OrderID CustomerID          CustomerName  \
# 0  ORD51058  CUST04879        Chaitanya Mane
# 1  ORD70248  CUST00177         Siddharth Sha
# 2  ORD43804  CUST04537  Nathaniel Chatterjee
# 3  ORD46367  CUST07605     pranit contractor
# 4  ORD32922  CUST03180    Hemang Chakraborty
#
#         City    Category  PaymentMode    Price  \
# 0  bangalore     Grocery  net_banking   904.48
# 1      DELHI      SPORTS  Net Banking  1823.76
# 2    chennai  electronic          Upi   770.67
# 3    Jaipur     Clothing          COD  2028.06
# 4    Amdavad   FURNITURE           cc   604.00
#
#    Quantity  DiscountPct  Rating    OrderDate  \
# 0       3.0           10     3.3   2023-04-24
# 1       4.0           20     5.0   04-01-2023
# 2       1.0            0     4.9   11/17/2024
# 3       1.0            0     2.9          NaN
# 4       4.0           10     3.7  14 Jan 2023
#
#    CustomerAge  \
# 0         29.0
# 1         38.0
# 2         40.0
# 3         41.0
# 4         44.0
#
# ...

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)   # show all columns
pd.set_option('display.width', 50)

# %%
df.shape
# Out:
# (106575, 15)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 106575 entries, 0 to 106574
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   OrderID       106575 non-null  str
#  1   CustomerID    106575 non-null  str
#  2   CustomerName  106575 non-null  str
#  3   City          104481 non-null  str
#  4   Category      106575 non-null  str
#  5   PaymentMode   103332 non-null  str
#  6   Price         106575 non-null  str
#  7   Quantity      106575 non-null  float64
#  8   DiscountPct   106575 non-null  int64
#  9   Rating        100129 non-null  float64
#  10  OrderDate     102358 non-null  str
#  11  CustomerAge   106575 non-null  float64
#  12  Email         99176 non-null   str
#  13  Phone         98117 non-null   str
#  14  ReviewText    93200 non-null   str
# dtypes: float64(3), int64(1), str(11)
# memory usage: 12.2 MB

# %%
df.describe()
# Out:
#             Quantity    DiscountPct  \
# count  106575.000000  106575.000000
# mean        2.066817       9.382125
# std         1.387769       9.176865
# min        -5.000000       0.000000
# 25%         1.000000       0.000000
# 50%         2.000000      10.000000
# 75%         3.000000      20.000000
# max         5.000000      25.000000
#
#               Rating    CustomerAge
# count  100129.000000  106575.000000
# mean        3.409874      39.678893
# std         1.306731      19.263288
# min         0.500000       0.000000
# 25%         2.600000      28.000000
# 50%         3.300000      38.000000
# 75%         4.100000      47.000000
# max         9.900000     150.000000

# %%
df.describe(include='object')   # summary of categorical/string columns
# Out:
# C:\Users\amitm\AppData\Local\Temp\ipykernel_11764\3111763311.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include='object')   # summary of categorical/string columns
#          OrderID CustomerID CustomerName  \
# count     106575     106575       106575
# unique    105000       9000        37440
# top     ORD72254  CUST01057  Charvi Dara
# freq           3         27           29
#
#              City Category       PaymentMode  \
# count      104481   106575            103332
# unique         56       35                24
# ...

# %%
df.dtypes
# Out:
# OrderID             str
# CustomerID          str
# CustomerName        str
# City                str
# Category            str
# PaymentMode         str
# Price               str
# Quantity        float64
# DiscountPct       int64
# Rating          float64
# OrderDate           str
# CustomerAge     float64
# Email               str
# Phone               str
# ReviewText          str
# dtype: object

# %%
df.columns
# Out:
# Index(['OrderID', 'CustomerID', 'CustomerName',
#        'City', 'Category', 'PaymentMode',
#        'Price', 'Quantity', 'DiscountPct',
#        'Rating', 'OrderDate', 'CustomerAge',
#        'Email', 'Phone', 'ReviewText'],
#       dtype='str')

# %%
df.nunique()
# Out:
# OrderID         105000
# CustomerID        9000
# CustomerName     37440
# City                56
# Category            35
# PaymentMode         24
# Price            88579
# Quantity            10
# DiscountPct          6
# Rating              91
# OrderDate         3367
# CustomerAge         66
# Email            39350
# Phone            96653
# ReviewText          14
# dtype: int64

# %%
df.isnull().sum()
# Out:
# OrderID             0
# CustomerID          0
# CustomerName        0
# City             2094
# Category            0
# PaymentMode      3243
# Price               0
# Quantity            0
# DiscountPct         0
# Rating           6446
# OrderDate        4217
# CustomerAge         0
# Email            7399
# Phone            8458
# ReviewText      13375
# dtype: int64

# %%
df["Quantity"].mean().round(2)*100
# Out:
# np.float64(206.99999999999997)

# %%
df.isna().mean().round(3)*100
# Out:
# OrderID          0.0
# CustomerID       0.0
# CustomerName     0.0
# City             2.0
# Category         0.0
# PaymentMode      3.0
# Price            0.0
# Quantity         0.0
# DiscountPct      0.0
# Rating           6.0
# OrderDate        4.0
# CustomerAge      0.0
# Email            6.9
# Phone            7.9
# ReviewText      12.5
# dtype: float64

# %%
df.DiscountPct.mean().round(2)
# Out:
# np.float64(9.38)

# %%
# Rows where CustomerName is missing (probably none here, but to understand the pattern)
df[df['City'].isna()].head()

# %%
df[df['City'].isna()].head()
# Out:
#       OrderID CustomerID      CustomerName City  \
# 44   ORD60845  CUST00989       LAKSH SAINI  NaN
# 110  ORD20288  CUST01667       BALVEER RAM  NaN
# 130  ORD42875  CUST07659      Arjun Shukla  NaN
# 177  ORD14310  CUST07857  Lavanya Bhargava  NaN
# 195  ORD97450  CUST04620     Harrison Gala  NaN
#
#       Category       PaymentMode       Price  \
# 44   Clothings               NaN     1312.67
# 110      Books                dc      344.35
# 130       toys  cash on delivery      953.44
# 177  furniture               upi  Rs.1575.61
# 195  Clothing        CREDIT CARD      873.31
#
#      Quantity  DiscountPct  Rating    OrderDate  \
# 44        4.0           10     2.6  12 Mar 2024
# 110       2.0            0     3.3   11/02/2024
# 130       5.0           25     4.3  10 Dec 2024
# 177       1.0            0     3.4   09/18/2023
# 195       1.0            5     1.2   2023-05-14
#
#      CustomerAge                         Email  \
# 44          35.0         laksh.saini@gmail.com
# ...

# %%
# City missing -> fill with 'Unknown'
df["City"] = df['City'].fillna('Unknown')

# %%
df.City.isnull().sum()
# Out:
# np.int64(0)

# %%
mode_payment= df['PaymentMode'].mode()[0]

# %%
mode_payment
# Out:
# 'UPI'

# %%
df['PaymentMode'] = df['PaymentMode'].fillna(df['PaymentMode'].mode()[0])

# %%
# PaymentMode missing -> fill with mode (most common value)
mode_payment = df['PaymentMode'].mode()[0]
df['PaymentMode'] = df['PaymentMode'].fillna(mode_payment)
mode_payment

# %%
# Rating missing -> we'll fill with median (this is a numeric column, but might currently be a string, so
# we'll do the final missing-value fill step after Section 4 (type cleaning) below)
df.isna().sum()
# Out:
# OrderID             0
# CustomerID          0
# CustomerName        0
# City                0
# Category            0
# PaymentMode         0
# Price               0
# Quantity            0
# DiscountPct         0
# Rating           6446
# OrderDate        4217
# CustomerAge         0
# Email            7399
# Phone            8458
# ReviewText      13375
# dtype: int64

# %%
df.duplicated().sum()   # how many fully duplicate rows there are
# Out:
# np.int64(1056)

# %%
df[df.duplicated(keep=False)]
# Out:
#          OrderID CustomerID     CustomerName  \
# 81      ORD61902  CUST03914     Yash Sawhney
# 121     ORD19515  CUST03317    Balendra Lata
# 130     ORD42875  CUST07659     Arjun Shukla
# 174     ORD97258  CUST04413    Jatin Borra
# 230     ORD88850  CUST05230       Falan Bumb
# ...          ...        ...              ...
# 106224  ORD20702  CUST04842      Turvi Lad
# 106266  ORD57327  CUST06398        Sai Misra
# 106399  ORD52908  CUST00065        Darsh Rau
# 106434  ORD17717  CUST00227   ZAYYAN SRIDHAR
# 106560  ORD68829  CUST01971    AARAV BOBAL
#
#             City     Category       PaymentMode  \
# 81      Calcutta         Book              UPI
# 121       madras       beauty       Net Banking
# 130      Unknown         toys  cash on delivery
# 174         Pune          Toy               COD
# 230      Lucknow      GROCERY       net banking
# ...          ...          ...               ...
# 106224   kolkata         toys               UPI
# ...

# %%
df[df.duplicated(keep=False)].sort_values('OrderID').head()
# Out:
#          OrderID CustomerID   CustomerName  \
# 12509   ORD10011  CUST05549  Dominic Nadig
# 46621   ORD10011  CUST05549  Dominic Nadig
# 54945  ORD100260  CUST08013    Krisha Mann
# 19142  ORD100260  CUST08013    Krisha Mann
# 77714  ORD100271  CUST01032     SIYA BORAH
#
#             City Category PaymentMode    Price  \
# 12509     Mumbai  grocery  Debit Card   986.17
# 46621     Mumbai  grocery  Debit Card   986.17
# 54945  bangalore    Sport          CC   492.31
# 19142  bangalore    Sport          CC   492.31
# 77714    Chennai  GROCERY          cc  4020.00
#
#        Quantity  DiscountPct  Rating  \
# 12509       2.0           10     1.1
# 46621       2.0           10     1.1
# 54945       1.0           25     5.0
# 19142       1.0           25     5.0
# 77714       1.0           20     1.6
#
#         OrderDate  CustomerAge  \
# 12509  09/23/2023         31.0
# 46621  09/23/2023         31.0
# 54945  05/07/2023         36.0
# 19142  05/07/2023         36.0
# ...

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (105519, 15)

# %%
# Check for duplicate IDs in the OrderID column (business rule: OrderID must be unique)
df['OrderID'].duplicated().sum()
# Out:
# np.int64(519)

# %%
dup_order_ids = df[df['OrderID'].duplicated(keep=False)].sort_values('OrderID')
dup_order_ids.head(10)
# Out:
#          OrderID CustomerID       CustomerName  \
# 32426  ORD100005  CUST05579          David Bal
# 20951  ORD100005  CUST05579          David Bal
# 96637  ORD100103  CUST06331    Neelima Misra
# 32568  ORD100103  CUST06331    Neelima Misra
# 42271  ORD100231  CUST02969       SIMON MANGAL
# 73117  ORD100231  CUST02969       SIMON MANGAL
# 64479  ORD100468  CUST03692        ONKAR VOHRA
# 81799  ORD100468  CUST03692        ONKAR VOHRA
# 26621  ORD100643  CUST02939       Varenya Lata
# 87213  ORD100643  CUST02939       Varenya Lata
#
#             City   Category  PaymentMode  \
# 32426     Delhi     Grocery  Net Banking
# 20951     Delhi     Grocery  Net Banking
# 96637  new delhi      books           CC
# 32568  new delhi      books           CC
# 42271     Delhi   FURNITURE           cc
# 73117     Delhi   FURNITURE           cc
# 64479   CALCUTTA      BOOKS  credit_card
# 81799   CALCUTTA      BOOKS  credit_card
# 26621     Delhi      BEAUTY         UPI
# ...

# %%
df['CustomerName'].unique()[1:35000:100]
# Out:
# <StringArray>
# [        'Siddharth Sha',
#            'Indali Kala',
#        'Chandresh Sarma',
#            'nikita kade',
#          'Wahab Agarwal',
#          'Saksham Jaggi',
#           'Jacob Prabhu',
#            'Abeer Golla',
#       'ayushman chander',
#     '  Brijesh Mander  ',
#  ...
#         'WIDISHA PILLAI',
#          'aachal bhalla',
#     '  Viraj Bhargava  ',
#    '  eiravati bansal  ',
#  '  Panini Srivastava  ',
#          'azad bhandari',
#      ' Balveer Deshmukh',
#        '  Anya Sangha  ',
#          ' Lucky Sachar',
#       'VIHAAN CHOUDHURY']
# Length: 350, dtype: str

# %%
df['CustomerName'].str.strip().str.title()
# Out:
# 0               Chaitanya Mane
# 1                Siddharth Sha
# 2         Nathaniel Chatterjee
# 3            Pranit Contractor
# 4           Hemang Chakraborty
#                   ...
# 106570                  Max Om
# 106571            Charan Manne
# 106572             Isaiah Wali
# 106573          Ladli Nazareth
# 106574               Yatin Rao
# Name: CustomerName, Length: 105519, dtype: str

# %%
df["new_name"] = df["CustomerName"].str.strip().str.title()

# %%
df["new_name"].unique()[:10]
# Out:
# <StringArray>
# [      'Chaitanya Mane',        'Siddharth Sha',
#  'Nathaniel Chatterjee',    'Pranit Contractor',
#    'Hemang Chakraborty',          'Ishaan Nair',
#        'Tara Nagarajan',          'Waida Kapur',
#           'Turvi Dugar',          'Kevin Amble']
# Length: 10, dtype: str

# %%
df['City'].unique()
# Out:
# <StringArray>
# [ 'bangalore',      'DELHI',    'chennai',
#     'Jaipur ',    'Amdavad',  'New Delhi',
#   'new delhi',    'Kolkata',  'hyderabad',
#      'mumbai',   ' Lucknow',    'LUCKNOW',
#      'jaipur',  'Bengaluru',   'Calcutta',
#      'MADRAS',  'bengaluru',     'Bombay',
#       'Poona',    'CHENNAI',       'pune',
#    'CALCUTTA',    'Lucknow',    'kolkata',
#   'AHMEDABAD',    ' Mumbai',  'Ahmedabad',
#        'PUNE',     'Jaipur',      'delhi',
#     'KOLKATA',     'Mumbai',    'Unknown',
#     ' Delhi ',  'HYDERABAD',   'calcutta',
#      'bombay',    'amdavad',  'NEW DELHI',
#      'JAIPUR',  'ahmedabad',      'poona',
#      'Madras',  'Bangalore',    'Chennai',
#     'lucknow',   'Banglore',     'madras',
#   'BANGALORE',   'mumbai  ',  'Hyderabad',
#      'BOMBAY',       'Pune',      'Delhi',
#    'banglore', ' Hyderabad',     'MUMBAI']
# Length: 57, dtype: str
