# %%
var = "string"

# %%
var.removeprefix("t")
# Out:
# 'string'

# %%
var.removeprefix("st")
# Out:
# 'ring'

# %%
var.removesuffix("ng")
# Out:
# 'stri'

# %%
var.replace("r", "RR")
# Out:
# 'stRRing'

# %%
var.replace("", "K")
# Out:
# 'KsKtKrKiKnKgK'

# %%
var1 = "first string"

# %%
var1.replace(" ", "--")
# Out:
# 'first--string'

# %%
var1.partition(" ")
# Out:
# ('first', ' ', 'string')

# %%
var1.split()
# Out:
# ['first', 'string']

# %%
var1
# Out:
# 'first string'

# %%
var1.split("i")
# Out:
# ['f', 'rst str', 'ng']

# %%
var1.partition("i")
# Out:
# ('f', 'i', 'rst string')

# %%
var1.rpartition("i")
# Out:
# ('first str', 'i', 'ng')

# %%
var2 = "     string^^^&&"

# %%
var2
# Out:
# '     string^^^&&'

# %%
var2.lstrip()
# Out:
# 'string^^^&&'

# %%
var2 = var2.rstrip("^&")

# %%
var2.strip()
# Out:
# 'string'

# %%
s1 = "hello world and python"

# %%
s1.partition("and")
# Out:
# ('hello world ', 'and', ' python')

# %%
s1.split("and")
# Out:
# ['hello world ', ' python']

# %%
l1 = s1.split()

# %%
l1
# Out:
# ['hello', 'world', 'and', 'python']

# %%
" ".join(l1)
# Out:
# 'hello world and python'

# %%
"--".join(l1)
# Out:
# 'hello--world--and--python'

# %%
s1.replace("l", "L")
# Out:
# 'heLLo worLd and python'

# %%
s1.removeprefix("hello")
# Out:
# ' world and python'

# %%
s1.removesuffix("thon")
# Out:
# 'hello world and py'

# %% [markdown]
# ## Tuple

# %%
t1 = ()

# %%
type(t1)
# Out:
# tuple

# %%
t1 = ("red", "white", "yellow", "pink", "black")

# %%
t1
# Out:
# ('red', 'white', 'yellow', 'pink', 'black')

# %%
t2 = ("blue", "purple", "orange")

# %%
t2
# Out:
# ('blue', 'purple', 'orange')

# %%
t1 + t2
# Out:
# ('red', 'white', 'yellow', 'pink', 'black', 'blue', 'purple', 'orange')

# %%
t1 + var
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 t1 + var
#
# TypeError: can only concatenate tuple (not "str") to tuple

# %%
t2*3
# Out:
# ('blue',
#  'purple',
#  'orange',
#  'blue',
#  'purple',
#  'orange',
#  'blue',
#  'purple',
#  'orange')

# %%
t1
# Out:
# ('red', 'white', 'yellow', 'pink', 'black')

# %%
t1[4]
# Out:
# 'black'

# %%
t1[1]
# Out:
# 'white'

# %%
t1[-2]
# Out:
# 'pink'

# %%
t3 = t1+t2

# %%
t3
# Out:
# ('red', 'white', 'yellow', 'pink', 'black', 'blue', 'purple', 'orange')

# %%
t3[1:6]
# Out:
# ('white', 'yellow', 'pink', 'black', 'blue')

# %%
t3[ : :-1]
# Out:
# ('orange', 'purple', 'blue', 'black', 'pink', 'yellow', 'white', 'red')

# %%
t3[2:10:-1]
# Out:
# ()

# %%
t3[10:2:-1]
# Out:
# ('orange', 'purple', 'blue', 'black', 'pink')

# %%
t3[7]
# Out:
# 'orange'

# %%
t3[12]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 t3[12]
#
# IndexError: tuple index out of range

# %%
t3[2:20]
# Out:
# ('yellow', 'pink', 'black', 'blue', 'purple', 'orange')

# %%
len(t3)
# Out:
# 8

# %%
t1
# Out:
# ('red', 'white', 'yellow', 'pink', 'black')

# %%
t1[3]  = "skyblue"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 t1[3]  = "skyblue"
#
# TypeError: 'tuple' object does not support item assignment

# %%
"pink" in t2
# Out:
# False

# %%
"pink" in t1
# Out:
# True

# %%
t4 = t2*3

# %%
t4
# Out:
# ('blue',
#  'purple',
#  'orange',
#  'blue',
#  'purple',
#  'orange',
#  'blue',
#  'purple',
#  'orange')

# %%
t4.count("blue")
# Out:
# 3

# %%
t4.index("orange", 3)
# Out:
# 5

# %%
t4.index("blue", 5)
# Out:
# 6

# %% [markdown]
# ## LIST

# %%
l = []

# %%
type(l)
# Out:
# list

# %%
l1 = ['red', 'white', 'yellow', 'pink', 'black']

# %%
l2 = ['blue', 'purple', 'orange']

# %%
l1
# Out:
# ['red', 'white', 'yellow', 'pink', 'black']

# %%
l2
# Out:
# ['blue', 'purple', 'orange']

# %%
l1+l2
# Out:
# ['red', 'white', 'yellow', 'pink', 'black', 'blue', 'purple', 'orange']

# %%
l2*3
# Out:
# ['blue',
#  'purple',
#  'orange',
#  'blue',
#  'purple',
#  'orange',
#  'blue',
#  'purple',
#  'orange']

# %%
l1[2]
# Out:
# 'yellow'

# %%
l1
# Out:
# ['red', 'white', 'yellow', 'pink', 'black']

# %%
l1[::-1]
# Out:
# ['black', 'pink', 'yellow', 'white', 'red']

# %%
t2
# Out:
# ('blue', 'purple', 'orange')

# %%
l2
# Out:
# ['blue', 'purple', 'orange']

# %%
t2 + l2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 t2 + l2
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
l1
# Out:
# ['red', 'white', 'yellow', 'pink', 'black']

# %%
l1[2]   = "orange"

# %%
l1
# Out:
# ['red', 'white', 'orange', 'pink', 'black']

# %%
lis = ["yellow", 23, 5.5, True, ('white', 'yellow'), ['white', 'pink',], {'yellow', 'pink',}, {1:'white', 2:'yellow'}, None]

# %%
len(lis)
# Out:
# 9

# %%
lis[-2]
# Out:
# {1: 'white', 2: 'yellow'}

# %%
lis[3]
# Out:
# True

# %%
lis[5][0]
# Out:
# 'white'

# %%
lis[0][-2]
# Out:
# 'o'

# %%
lis
# Out:
# ['yellow',
#  23,
#  5.5,
#  True,
#  ('white', 'yellow'),
#  ['white', 'pink'],
#  {'pink', 'yellow'},
#  {1: 'white', 2: 'yellow'},
#  None]

# %%
lis[0][1]
# Out:
# 'e'

# %%
lis[6][1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 lis[6][1]
#
# TypeError: 'set' object is not subscriptable

# %%
lis[7][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 lis[7][0]
#
# KeyError: 0

# %%
lis[7][2]
# Out:
# 'yellow'

# %%
tup = ('yellow',
 23,
 5.5,
 True,
 ('white', 'yellow'),
 ['white', 'pink'],
 {'pink', 'yellow'},
 {1: 'white', 2: 'yellow'},
 None)

# %%
tup[4][1]
# Out:
# 'yellow'

# %%
tup[6][0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 tup[6][0]
#
# TypeError: 'set' object is not subscriptable

# %%
lis[0].upper()
# Out:
# 'YELLOW'

# %%
lis[4].index("yellow")
# Out:
# 1
